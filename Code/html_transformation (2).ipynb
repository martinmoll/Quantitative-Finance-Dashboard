# %% [markdown]
# **Convert ipynb to HTML in Colab**
#
# You are suggested to submit both ipynb and HTML formats on canvas.
#
# The HTML version allows us to see that results you generated on your machine.
#
# The ipynb version will be used to replicate your results. If we cannot replicate the results, or if the code breaks, you won't receive any marks for that question.

# %% [markdown]
# Instruction:
#
# 1.   Download the ipynb, which you want to convert, on your local computer.
# 2.   Run the code below to upload the ipynb.
#
# The html version will be downloaded automatically on your local machine.

# %%
# Upload ipynb
from google.colab import files
f = files.upload()

# Convert ipynb to html
import subprocess
file0 = list(f.keys())[0]
_ = subprocess.run(["pip", "install", "nbconvert"])
_ = subprocess.run(["jupyter", "nbconvert", file0, "--to", "html"])

# download the html
files.download(file0[:-5]+"html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Upload ipynb
# ----> 2 from google.colab import files
#       3 f = files.upload()
#       5 # Convert ipynb to html
#
# ModuleNotFoundError: No module named 'google.colab'
